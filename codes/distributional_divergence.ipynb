# %%
import pandas as pd
import numpy as np
import re
import scipy
from scipy import stats

# %%
data = pd.read_csv('../data/csv_data/dtm_data.csv')
data.head()
# Out:
#          id  length      date country       publisher  \
# 0  88033929     554  21-10-01      US  New York Times
# 1  88035715    7205  21-10-01      US  New York Times
# 2  88046027     300  21-10-03      US        Fox News
# 3  88046227     501  21-10-03      US  New York Times
# 4  88055023    1417  21-10-05      US  New York Times
#
#                                              snippet  \
# 0  A pilot program hints at an eventual end to Au...
# 1  Merck says a trial shows it has produced the f...
# 2  Fauci defends California school vaccine mandat...
# 3  Israel will require a booster shot to be consi...
# 4  How Do Thousands Prepare for a Climate Summit?...
#
#                                                 body  \
# 0   A pilot program hints at an eventual end to A...
# 1   Covid News : U.S. Parents ' Views Are Shiftin...
# 2   " I have been and I still am in favor of thes...
# 3   Israel will require a booster shot to be cons...
# 4   In a few weeks , an estimated 20,000 minister...
#
#                                          body_tokens  \
# 0  ['A', 'pilot', 'program', 'hints', 'at', 'an',...
# 1  ['Covid', 'News', 'U.S.', 'Parents', 'Views', ...
# 2  ['I', 'have', 'been', 'and', 'I', 'still', 'am...
# 3  ['Israel', 'will', 'require', 'a', 'booster', ...
# 4  ['In', 'a', 'few', 'weeks', 'an', 'estimated',...
#
#                               body_tokens_normalized  \
# 0  ['pilot', 'program', 'hints', 'eventual', 'end...
# 1  ['covid', 'news', 'us', 'parents', 'views', 's...
# 2  ['favor', 'kinds', 'mandates', 'fauci', 'said'...
# 3  ['israel', 'require', 'booster', 'shot', 'cons...
# 4  ['weeks', 'estimated', 'ministers', 'activists...
#
#                                       snippet_tokens  \
# 0  ['A', 'pilot', 'program', 'hints', 'at', 'an',...
# 1  ['Merck', 'says', 'a', 'trial', 'shows', 'it',...
# 2  ['Fauci', 'defends', 'California', 'school', '...
# 3  ['Israel', 'will', 'require', 'a', 'booster', ...
# 4  ['How', 'Do', 'Thousands', 'Prepare', 'for', '...
#
#                                       trunc_sentence  \
# 0  ["A pilot program hints at an eventual end to ...
# 1  ['Covid News : U', "Parents ' Views Are Shifti...
# 2  ['" I have been and I still am in favor of the...
# 3  ['Israel will require a booster shot to be con...
# 4  ['In a few weeks , an estimated 20,000 ministe...
#
#                                      sentiment_score  neg_sentim_score  \
# 0  [{'label': 'NEGATIVE', 'score': 0.978422582149...          0.400000
# 1  [{'label': 'NEGATIVE', 'score': 0.732781469821...          0.666667
# 2  [{'label': 'POSITIVE', 'score': 0.997584581375...          0.500000
# 3  [{'label': 'NEGATIVE', 'score': 0.997277677059...          0.800000
# 4  [{'label': 'POSITIVE', 'score': 0.997138023376...          0.500000
#
#                                  body_tokens_reduced
# 0  ['pilot', 'program', 'hints', 'eventual', 'end...
# 1  ['covid', 'news', 'parents', 'views', 'shiftin...
# 2  ['favor', 'kinds', 'mandates', 'fauci', 'abc',...
# 3  ['israel', 'require', 'booster', 'shot', 'cons...
# 4  ['weeks', 'estimated', 'ministers', 'activists...

# %%
[re.sub('[^0-9a-zA-Z]+', '', k) for k in data['body_tokens_normalized'][0].split(',')]
# Out:
# ['pilot',
#  'program',
#  'hints',
#  'eventual',
#  'end',
#  'australia',
#  'hotel',
#  'quarantine',
#  'system',
#  'australian',
#  'state',
#  'new',
#  'south',
#  'wales',
#  'allow',
#  'returning',
#  'international',
#  'travelers',
#  'quarantine',
#  'home',
#  'starting',
#  'end',
#  'month',
#  'possibly',
#  'signaling',
#  'beginning',
#  'end',
#  'country',
#  'strict',
#  'hotel',
#  'quarantine',
#  'system',
#  'pilot',
#  'program',
#  'allow',
#  'fully',
#  'vaccinated',
#  'people',
#  'isolate',
#  'homes',
#  'days',
#  'spend',
#  'weeks',
#  'government',
#  'appointed',
#  'facility',
#  'stuart',
#  'ayres',
#  'new',
#  'south',
#  'wales',
#  'government',
#  'official',
#  'announced',
#  'friday',
#  'police',
#  'employ',
#  'location',
#  'based',
#  'tracking',
#  'facial',
#  'recognition',
#  'technology',
#  'monitor',
#  'new',
#  'arrivals',
#  'movements',
#  'added',
#  'similar',
#  'technology',
#  'western',
#  'australia',
#  'november',
#  'program',
#  'help',
#  'country',
#  'plan',
#  'steps',
#  'ending',
#  'current',
#  'system',
#  'mr',
#  'ayres',
#  'said',
#  'news',
#  'conference',
#  've',
#  'got',
#  'able',
#  'learn',
#  'happens',
#  'people',
#  'home',
#  'based',
#  'quarantine',
#  'australia',
#  'reopen',
#  'rid',
#  'lockdowns',
#  'engage',
#  'world',
#  'spend',
#  'weeks',
#  'hotel',
#  'room',
#  'spots',
#  'country',
#  'quarantine',
#  'system',
#  'hard',
#  'come',
#  'border',
#  'closed',
#  'returning',
#  'citizens',
#  'faced',
#  'flight',
#  'cancellations',
#  'country',
#  'tight',
#  'limit',
#  'number',
#  'arrivals',
#  'july',
#  'cap',
#  'halved',
#  'passengers',
#  'week',
#  'complicating',
#  'australians',
#  'efforts',
#  'return',
#  'home',
#  'announcement',
#  'pilot',
#  'program',
#  'comes',
#  'new',
#  'south',
#  'wales',
#  'reaches',
#  'key',
#  'vaccination',
#  'goal',
#  'half',
#  'residents',
#  'age',
#  'received',
#  'doses',
#  'covid',
#  'vaccine',
#  'percent',
#  'state',
#  'battling',
#  'country',
#  'severe',
#  'outbreaks',
#  'new',
#  'cases',
#  'deaths',
#  'recorded',
#  'friday',
#  'greg',
#  'hunt',
#  'federal',
#  'health',
#  'minister',
#  'announced',
#  'australia',
#  'surpassed',
#  'goal',
#  'providing',
#  'dose',
#  'vaccine',
#  'percent',
#  'people',
#  'age',
#  'significant',
#  'important',
#  'milestone',
#  'news',
#  'conference',
#  'friday',
#  'victoria',
#  'neighbors',
#  'new',
#  'south',
#  'wales',
#  'administered',
#  'covid',
#  'vaccine',
#  'dose',
#  'percent',
#  'population',
#  'ease',
#  'restrictions',
#  'starting',
#  'late',
#  'friday',
#  'night',
#  'vast',
#  'majority',
#  'businesses',
#  'remain',
#  'closed',
#  'curfew',
#  'place',
#  'melbourne',
#  'largest',
#  'city',
#  'australia',
#  'soon',
#  'begin',
#  'vaccinating',
#  'people',
#  'moderna',
#  'vaccine',
#  'addition',
#  'vaccines',
#  'produced',
#  'astrazeneca',
#  'pfizer',
#  'biontech',
#  'doses',
#  'moderna',
#  'vaccine',
#  'expected',
#  'arrive',
#  'end',
#  'weekend',
#  'mr',
#  'hunt',
#  'said',
#  'response',
#  'australia',
#  'ongoing',
#  'outbreak',
#  'new',
#  'zealand',
#  'resume',
#  'quarantine',
#  'free',
#  'travel',
#  'countries',
#  'weeks',
#  'grant',
#  'robertson',
#  'deputy',
#  'prime',
#  'minister',
#  'announced',
#  'friday',
#  'country',
#  'suspended',
#  'called',
#  'trans',
#  'tasman',
#  'bubble',
#  'july',
#  'cases',
#  'began',
#  'rise',
#  'australia',
#  'new',
#  'zealand',
#  'city',
#  'auckland',
#  'home',
#  'country',
#  'population',
#  'eliminate',
#  'delta',
#  'variant',
#  'new',
#  'zealand',
#  'far',
#  'recorded',
#  'coronavirus',
#  'cases',
#  'death',
#  'latest',
#  'outbreak']

# %%
data['body_tokens_normalized'] = data['body_tokens_normalized'].apply(lambda x: [re.sub('[^0-9a-zA-Z]+', '', k)
                                                                     for k in x.split(',')])

# %%
nyt = data[data['publisher'] == 'New York Times'].copy()
fox = data[data['publisher'] == 'Fox News'].copy()

# %%
nytWords = set(nyt['body_tokens_normalized'].sum())
foxWords = set(fox['body_tokens_normalized'].sum())

# %%
overlapWords = nytWords & foxWords

overlapWordsDict = {word: index for index, word in enumerate(overlapWords)}
overlapWordsDict['covid']
# Out:
# 38645

# %%
def makeProbsArray(dfColumn, overlapDict):
    words = dfColumn.sum()
    countList = [0] * len(overlapDict)
    for word in words:
        try:
            countList[overlapDict[word]] += 1
        except KeyError:
            #The word is not common so we skip it
            pass
    countArray = np.array(countList)
    return countArray / countArray.sum()

nytProbArray = makeProbsArray(nyt['body_tokens_normalized'], overlapWordsDict)
foxProbArray = makeProbsArray(fox['body_tokens_normalized'], overlapWordsDict)
foxProbArray.sum()
# Out:
# 1.0

# %%
nyt_foxDivergence = scipy.stats.entropy(nytProbArray, foxProbArray)
print(nyt_foxDivergence)
ken_whDivergence = scipy.stats.entropy(foxProbArray, nytProbArray)
print(ken_whDivergence)
# Out:
# 0.06855089382623267
# 0.07118029246931237

# %%
nyt_foxDivergence_ew = scipy.special.kl_div(nytProbArray, foxProbArray)
kl_df = pd.DataFrame(list(overlapWordsDict.keys()), columns = ['word'], index = list(overlapWordsDict.values()))
kl_df = kl_df.sort_index()
kl_df['elementwise divergence'] = nyt_foxDivergence_ew
kl_df[:10]
# Out:
#          word  elementwise divergence
# 0                        6.777982e-06
# 1      angela            5.995161e-07
# 2     cobbled            5.202145e-07
# 3    farthest            1.699706e-07
# 4  underlines            5.854059e-07
# 5     puzzled            3.107422e-07
# 6  indicating            2.502555e-07
# 7    strident            6.496174e-07
# 8      biopic            1.416422e-07
# 9       gecko            2.832844e-08

# %%
kl_df.sort_values(by='elementwise divergence', ascending=False)[:10]
# Out:
#           word  elementwise divergence
# 29593       mr                0.002295
# 3760    credit                0.000786
# 12497    image                0.000750
# 10515       ms                0.000635
# 31190     clip                0.000349
# 29761      fox                0.000275
# 5205   gutfeld                0.000254
# 7042   swisher                0.000244
# 9926      york                0.000242
# 7091     doyle                0.000235
